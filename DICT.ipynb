# %%
#Dictionary programs from Set(3.4).

# %%
employee={"Name":"Shubham","Department":"Technical","Salary":120000,"Designation":"Engineer"}

print(employee.get("Name"))
print(employee.get("Department"))
print(employee.get("Salary"))
print(employee.get("Designation"))
# Out:
# Shubham
# Technical
# 120000
# Engineer

# %%
student={"name":"utsav","city":"muradnagar"}

student.update({"email":"xyz123@gmail.com","phone number":"123xxxx789"})
print(student)
# Out:
# {'name': 'utsav', 'city': 'muradnagar', 'email': 'xyz123@gmail.com', 'phone number': '123xxxx789'}

# %%
employee={"name":"amit","salary":45000}
print(employee)

employee.update({"salary":52000})
print(employee)
# Out:
# {'name': 'amit', 'salary': 45000}
# {'name': 'amit', 'salary': 52000}

# %%
student={"name":"aditya","college":"xyz college","branch":"CSE"}
print(student)

student.pop("name")
print(student)
student.popitem()
print(student)
# Out:
# {'name': 'aditya', 'college': 'xyz college', 'branch': 'CSE'}
# {'college': 'xyz college', 'branch': 'CSE'}
# {'college': 'xyz college'}

# %%
student={"Roll":101,"Name":"Rahul","Branch":"CSE","Sem":5}

print(student.keys())   
print(student.values())
print(student.items())
# Out:
# dict_keys(['Roll', 'Name', 'Branch', 'Sem'])
# dict_values([101, 'Rahul', 'CSE', 5])
# dict_items([('Roll', 101), ('Name', 'Rahul'), ('Branch', 'CSE'), ('Sem', 5)])

# %%
student={"Roll":101,"Name":"Rahul","Branch":"CSE","Sem":5}

if "Name" in student:
    print("Key Found")

else:
    print("Key Not Found")
# Out:
# Key Found

# %%
student={"Roll":101,"Name":"Rahul","Branch":"CSE","Sem":5}

a=list(student)
print(a)
print(len(a))
# Out:
# ['Roll', 'Name', 'Branch', 'Sem']
# 4

# %%
keys=["ID","Name","Age","City"]
values=[101,"Ankit",20,"Delhi"]

combined_keys_values=dict(zip(keys,values))
print(combined_keys_values)
# Out:
# {'ID': 101, 'Name': 'Ankit', 'Age': 20, 'City': 'Delhi'}

# %%
students={"Student_1":{"Name":"Prince","Branch":"CSE","Semester":2,"CGPA":8},
          "Student_2":{"Name":"Ansh","Branch":"Ai-Ml","Semester":2,"CGPA":7},
          "Student_3":{"Name":"Shubham","Branch":"CSE","Semester":2,"CGPA":8}}

print(students)
# Out:
# {'student_1': {'Name': 'Prince', 'Branch': 'CSE', 'Semester': 2, 'CGPA': 8}, 'Student_2': {'Name': 'Ansh', 'Branch': 'Ai-Ml', 'Semester': 2, 'CGPA': 7}, 'Student_3': {'Name': 'Shubham', 'Branch': 'CSE', 'Semester': 2, 'CGPA': 8}}

# %%
students={"Student_1":{"Name":"Prince","Branch":"CSE","Semester":2,"CGPA":8},
          "Student_2":{"Name":"Ansh","Branch":"Ai-Ml","Semester":2,"CGPA":7},
          "Student_3":{"Name":"Shubham","Branch":"CSE","Semester":2,"CGPA":8}}

print(students["Student_2"]["Name"])
print(students["Student_3"]["Branch"])
print(students["Student_1"]["CGPA"])
# Out:
# Ansh
# CSE
# 8

# %%
departments={"CSE":{"HOD Name":"Vijay","Faculties":15,"Students":420},
             "ECE":{"HOD Name":"Amit","Faculties":11,"Students":388},
             "ME":{"HOD Name":"Sachin","Faculties":10,"Students":50}}

print(departments["ECE"]["HOD Name"])
print(departments["CSE"]["Students"])
departments.update({"ME":{"HOD Name":"Sachin","Faculties":9,"Students":50}})
print(departments["ME"]["Faculties"])
departments.update({"CIVIL":{"HOD Name":"Vinayak","Faculties":7,"Students":43}})
print(departments.keys())
print(departments)
# Out:
# Amit
# 420
# 9
# dict_keys(['CSE', 'ECE', 'ME', 'CIVIL'])
# {'CSE': {'HOD Name': 'Vijay', 'Faculties': 15, 'Students': 420}, 'ECE': {'HOD Name': 'Amit', 'Faculties': 11, 'Students': 388}, 'ME': {'HOD Name': 'Sachin', 'Faculties': 9, 'Students': 50}, 'CIVIL': {'HOD Name': 'Vinayak', 'Faculties': 7, 'Students': 43}}
