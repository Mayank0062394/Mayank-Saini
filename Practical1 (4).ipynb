# %%
# It is a Mini-Project for "Smartcampus Automated Pass & Utility Calculator".

print("="*70)
print("        SMARTCAMPUS AUTOMATED PASS & UTILITY CALCULATOR")
print("="*70)
user_type=int(input("Select your Category (1:Student, 2:Faculty/Staff) :"))

if user_type==1:
    user_subtype=input("Select your Sub-Category (UG/PG) : ")
    if user_subtype=="UG" or user_subtype=="ug":
        basefee=500
        user_cgpa=float(input("Enter Student's CGPA (0.0-10.0) :"))
        if user_cgpa>=8.5:
            discount="20%"
            after_discount=(500*20)/100
           
        elif user_cgpa<=8.49 and user_cgpa>=7.5:
            discount="10%"
            after_discount=(500*10)/100
            
        else:
            discount="0%"
            after_discount=0  
        vehicle_type=int(input("Select Vehicle Parking Permit (1:None, 2:Two-Wheeler, 4:Four-Wheeler) :"))         
        elec_consumption=float(input("Enter Monthly Electricity Consumption(in kwh) :")) 
       
    elif user_subtype=="PG" or user_subtype=="pg":
        basefee=350
        user_cgpa=float(input("Enter Student's CGPA (0.0-10.0) :"))
        if user_cgpa>=8.5:
            discount="20%"
            after_discount=(350*20)/100
                
        elif user_cgpa<8.49 and user_cgpa>7.5:
            discount="10%"
            after_discount=(350*10)/100
                
        else:
            discount="0%"
            after_discount=0
        vehicle_type=int(input("Select Vehicle Parking Permit (1:None, 2:Two-Wheeler, 4:Four-Wheeler) :"))           
        elec_consumption=float(input("Enter Monthly Electricity Consumption(in kwh) :")) 
               
    else:
        print("ERROR")
    if vehicle_type==1:
        vehicle_charge=0
    elif vehicle_type==2:
        vehicle_charge=200
    elif vehicle_type==4:
        vehicle_charge=600+150

elif user_type==2:  
    user_subtype=int(input("Select your Sub-Category (1:Resident, 2:Visiting/Guest) :"))
    if user_subtype==1:
        basefee=800
        service=float(input("Enter faculty's year of service :"))
        if service>10:
            discount="15%"
            after_discount=(800*15)/100       

        else:
            discount="0%"
            after_discount=0
        vehicle_type=int(input("Select Vehicle Parking Permit (1:None, 2:Two-Wheeler, 4:Four-Wheeler) :"))
        elec_consumption=float(input("Enter Monthly Electricity Consumption(in kwh) :")) 
       
    elif user_subtype==2:
        basefee=1200
        service=float(input("Enter faculty's year of service :"))      
        if service>10:
            discount="15%"
            after_discount=(1200*15)/100

        else:
            discount="0%"
            after_discount=0
        vehicle_type=int(input("Select Vehicle Parking Permit (1:None, 2:Two-Wheeler, 4:Four-Wheeler) :"))      
        elec_consumption=float(input("Enter Monthly Electricity Consumption(in kwh) :")) 
            
    else:
        print("ERROR")

    if vehicle_type==1:
        vehicle_charge=0
    elif vehicle_type==2:
        vehicle_charge=200
    elif vehicle_type==4:
        vehicle_charge=600        

else:
    print("ERROR")

if elec_consumption<=100 and elec_consumption>=0:
    fixed_charge=50
    elec_bill=elec_consumption*3.00+50
elif elec_consumption<=300 and elec_consumption>100:
    fixed_charge=100
    elec_bill=(elec_consumption-100)*5.00+100*3.00+100+50
elif elec_consumption<=500 and elec_consumption>300:
    fixed_charge=150
    elec_bill=(elec_consumption-300)*7.50+100*3.00+200*5.00+150+150
elif elec_consumption>500:
    fixed_charge=250
    elec_bill=(elec_consumption-500)*10.00+100*3.00+200*5.00+200*7.50+250+300

total=basefee-after_discount+vehicle_charge
total1=total+elec_bill


if user_type==1 or user_type==2:
    if user_subtype=="UG" or user_subtype=="PG" or user_subtype=="ug" or user_subtype=="pg" or user_subtype==1 or user_subtype==2:
        
    
        print("-"*70)
        print("                 CALCULATED INVOICE BREAKDOWN")
        print("-"*70)

        print("Base Access Pass Fee :Rs.{}".format(basefee))
        if user_type==2 or user_subtype==1 or user_subtype==2:
            print("Service Discount({}) :-Rs.{}".format(discount,after_discount))
        else:
            print("Merit Discount({}) :-Rs.{}".format(discount,after_discount))
        if user_type==1:
            if vehicle_type==1:
                print("Parking Fee(None) :Rs.{}".format(vehicle_charge))
            elif vehicle_type==2:
                print("Parking Fee(2-Wheeler) :Rs.{}".format(vehicle_charge))
            else: 
                if vehicle_type==4:
                    print("Parking Fee(4-Wheeler) With Student Peak Surcharge(Rs.150) :Rs.{}".format(vehicle_charge))
        else:
            if vehicle_type==1:
                print("Parking Fee(None) :Rs.{}".format(vehicle_charge))
            elif vehicle_type==2:
                print("Parking Fee(2-Wheeler) :Rs.{}".format(vehicle_charge))
            else: 
                if vehicle_type==4:
                    print("Parking Fee(4-Wheeler) :Rs.{}".format(vehicle_charge))

        print("Net Pass & Parking Total :Rs.{}".format(total))

        print("-"*70)
        if elec_consumption==0:
            print("Electricity Bill({}kwh) :Rs.{} (Fixed Charge Rs.{})".format(elec_consumption,elec_bill,fixed_charge))
        else:
            print("Electricity Bill({}kwh) :Rs.{} (Slab Calculated + Fixed Charge Rs.{})".format(elec_consumption,elec_bill,fixed_charge))
        print("-"*70)
        print("Total Monthly Payable :Rs.{}".format(total1))
        
        print("="*70)
# Out:
# ...
#         SMARTCAMPUS AUTOMATED PASS & UTILITY CALCULATOR
# ...
# Select your Category (1:Student, 2:Faculty/Staff) : 1
# Select your Sub-Category (UG/PG) :  UG
# Enter Student's CGPA (0.0-10.0) : 8.8
# Select Vehicle Parking Permit (1:None, 2:Two-Wheeler, 4:Four-Wheeler) : 4
# Enter Monthly Electricity Consumption(in kwh) : 340
# ----------------------------------------------------------------------
#                  CALCULATED INVOICE BREAKDOWN
# ----------------------------------------------------------------------
# Base Access Pass Fee :Rs.500
# Merit Discount(20%) :-Rs.100.0
# Parking Fee(4-Wheeler) With Student Peak Surcharge(Rs.150) :Rs.750
# Net Pass & Parking Total :Rs.1150.0
# ----------------------------------------------------------------------
# Electricity Bill(340.0kwh) :Rs.1900.0 (Slab Calculated + Fixed Charge Rs.150)
# ----------------------------------------------------------------------
# Total Monthly Payable :Rs.3050.0
# ...
