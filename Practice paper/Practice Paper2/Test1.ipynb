# %%
name,age,city,salary="Mayank",19,"Modinagar",100000
print(name,age,city,salary)
# Out:
# Mayank 19 Modinagar 100000

# %%
a=5
b=6
print(a,b)
a,b=b,a
print(a,b)
# Out:
# 5 6
# 6 5

# %%
number_1=int(input("Enter the number : "))
number_2=int(input("Enter the number : "))
sum=number_1+number_2
print(sum)
# Out:
# Enter the number :  2
# Enter the number :  3
# 5

# %%
name="Mayank"
type(name)
age=19
type(age)
decimal_number=99.21
type(decimal_number)
# Out:
# float

# %%
name,age,numbers="Mayank",19,76.20
print(name,age,numbers)
# Out:
# Mayank 19 76.2

# %%
a,b,c=12,12,12
print(a,b,c)
# Out:
# 12 12 12

# %%
a=19
print(a)
del(a)
print(a)
# Out:
# 19
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 print(a)
#       3 del(a)
# ----> 4 print(a)
#
# NameError: name 'a' is not defined

# %%
age=int(input("Enter the age"))
print(f"you are {age} years old")
# Out:
# Enter the age 19
# you are 19 years old

# %%
a=input("Enter the first name")
b=input("Enter the last name")
print(a,b)
# Out:
# Enter the first name Mayank
# Enter the last name Saini
# Mayank Saini

# %%
a=input("enter the employee's name")
b=int(input("Enter the employee's monthly salary"))
A=b*12
print(A)
# Out:
# enter the employee's name Prince
# Enter the employee's monthly salary 150000
# 1800000
