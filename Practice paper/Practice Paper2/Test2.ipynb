# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# Enter first number 2
# Enter second number 4
# 6
# -2
# 8
# 0.5
# 0
# 2
# 16

# %%
a=int(input("Enter a number"))
print(a)
a+=10
print(a)
a-=5
print(a)
a*=2
print(a)
a/=3
print(a)
# Out:
# Enter a number 4
# 4
# 14
# 9
# 18
# 6.0

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a==b)
print(a!=b)
print(a>b)
print(a<=b)
# Out:
# Enter first number 2
# Enter second number 5
# False
# True
# False
# True

# %%
sub1=int(input("Enter marks of first subject"))
sub2=int(input("Enter marks of second subject"))
if(sub1&sub2>=35):
    print("Pass")
    print("Eligible for scholarship")
# Out:
# Enter marks of first subject 45
# Enter marks of second subject 36
# Pass

# %%
sentence=str(input("Enter a sentence"))
word=input("Enter a word")
print(word in sentence)
# Out:
# Enter a sentence Welcome to rdec
# Enter a word to
# True

# %%
sentence=input("Enter a sentence")
word=input("Enter a word")
print(word not in sentence)
# Out:
# Enter a sentence my name is mayank
# Enter a word ok
# True

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a==b)
c=int(input("Enter third number"))
print(a==c)
# Out:
# Enter first number 4
# Enter second number 4
# True
# Enter third number 4
# True

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a!=b)
c=int(input("Enter third number"))
print(a!=c)
# Out:
# Enter first number 4
# Enter second number 5
# True
# Enter third number 7
# True

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a&b)
print(a|b)
# Out:
# Enter first number 3
# Enter second number 5
# 1
# 7

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a^b)
print(~a)
# Out:
# Enter first number 3
# Enter second number 4
# 7
# -4

# %%
a=int(input("Enter a number"))
print(a<<2)
print(a>>2)
# Out:
# Enter a number 2
# 8
# 0

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))
print(a>b)
print(c>a)
# Out:
# Enter first number 4
# Enter second number 2
# Enter third number 3
# True
# False
