# %%
a=4
print(a)
type(a)
b=4.7
print(b)
type(b)
# Out:
# 4
# 4.7
# float

# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**2)
# Out:
# Enter first number 8
# Enter second number 4
# 12
# 4
# 32
# 2.0
# 2
# 0
# 64

# %%
a=int(input("Enter a number"))
a=float(a)
print(a)
a=complex(a)
print(a)
# Out:
# Enter a number 4
# 4.0
# (4+0j)

# %%
a=4+5j
print(a)
print(a.real)
print(a.imag)
b=complex(input("Enter a complex number"))
print(b)
print(b.real)
print(b.imag)
# Out:
# (4+5j)
# 4.0
# 5.0
# Enter a complex number 3-9j
# (3-9j)
# 3.0
# -9.0

# %%
a=float(input("enter first float value"))
b=float(input("enter second float value"))
c=float(input("enter third float value"))
average=(a+b+c)/3
print(f"average of {a},{b},{c} is {average}")
# Out:
# enter first float value 4.09
# enter second float value 5.34
# enter third float value 4.98
# average of 4.09,5.34,4.98 is 4.803333333333334

# %%
a=10
b=3.09
c=5+2j
sum_int_float=a+b
print(sum_int_float,type(sum_int_float))
sum_float_complex=b+c
print(sum_float_complex,type(sum_float_complex))
# Out:
# 13.09 <class 'float'>
# (8.09+2j) <class 'complex'>

# %%
integer=int(input("Enter an integer number"))
decimal=float(input("Enter a float number"))
comp_number=complex(input("Enter a complex number"))
print(integer,type(integer))
print(decimal,type(decimal))
print(comp_number,type(comp_number))
# Out:
# Enter an integer number 56
# Enter a float number 45.92
# Enter a complex number 5+9j
# 56 <class 'int'>
# 45.92 <class 'float'>
# (5+9j) <class 'complex'>

# %%
a=245
b=37
c=-128.75
power=pow(a,2)
print(f"square of {a} is {power}")
absolute=abs(c)
print(f"absolute of c is {absolute}")
maximum=max(a,b,c)
print(f"maximum in {a} {b} {c} is {maximum}")
minimum=min(a,b,c)
print(f"minimum in {a} {b} {c} is {minimum}")
average=(a+b+c)/3
print(f"Average of {a} {b} {c} is {average}")
# Out:
# square of 245 is 60025
# absolute of c is 128.75
# maximum in 245 37 -128.75 is 245
# minimum in 245 37 -128.75 is -128.75
# Average of 245 37 -128.75 is -389039.5833333333

# %%
c1=6+9j
c2=4-7j
a=c1+c2
print(f"addition of {c1} and {c2} is {a}")
b=c1*c2
print(f"multiplication of {c1} and {c2} is {b}")
c=abs(c1)
print(f"magnitude of {c1} is {c}")
d=abs(c2)
print(f"magnitude of {c2} is {d}")
address1=id(c1)
print(f"address of {c1} is {address1}")
address2=id(c2)
print(f"address of {c2} is {address2}")
# Out:
# addition of (6+9j) and (4-7j) is (10+2j)
# multiplication of (6+9j) and (4-7j) is (87-6j)
# magnitude of (6+9j) is 10.816653826391969
# magnitude of (4-7j) is 8.06225774829855
# address of (6+9j) is 2305829873072
# address of (4-7j) is 2305829874864

# %%
name=input("enter your name")
age=input("enter your age")
course=input("enter your course")
univer=input("enter your university")
city=input("enter your city")
print("----------------------")
print("   STUDENT PROFILE    ")
print("----------------------")
print(f"Name       :{name}")
print(f"Age        :{age}")
print(f"Course     :{course}")
print(f"University :{univer}")
print(f"City       :{city}")
print("----------------------")
# Out:
# enter your name Mayank Saini
# enter your age 19
# enter your course Btech
# enter your university Aktu
# enter your city Modinagar
# ----------------------
#    STUDENT PROFILE
# ----------------------
# Name       :Mayank Saini
# Age        :19
# Course     :Btech
# University :Aktu
# City       :Modinagar
# ----------------------
