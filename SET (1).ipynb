# %%
#Set programs from Practice Set(3.5).

# %%
numbers=set()
numbers.update([25,35,45])
print(numbers)
# Out:
# {25, 35, 45}

# %%
numbers={1,2,3,4,5,6,7}
numbers.remove(4)
print(numbers)
numbers.discard(6)
print(numbers)
numbers.pop()
print(numbers)
# Out:
# {1, 2, 3, 5, 6, 7}
# {1, 2, 3, 5, 7}
# {2, 3, 5, 7}

# %%
set1 = {1,3,5,7,9}
set2 = {2,4,6,8}

print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# set()
# {1, 3, 5, 7, 9}
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
set1 = {1,3,5,7,9}
set2 = {2,4,6,8}
print(set1.isdisjoint(set2))
# Out:
# True

# %%
numbers=[1,2,3,4,5,6,7,8,4,5,4,4]

numbers1=set(numbers)
print(numbers1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
student1={"Python","Java","SQL","Excel"}
student2={"Python","C","Excel","Power BI"}

print(student1.intersection(student2))
# Out:
# {'Python', 'Excel'}

# %%
science_club={"Aman","Riya","Rahul","Priya","Ankit"}
coding_club={"Rahul","Ankit","Simran","Rohit","Riya"}

print(science_club.union(coding_club))
print(science_club.intersection(coding_club))
print(science_club.difference(coding_club))
print(coding_club.difference(science_club))
print(science_club.intersection(coding_club))
coding_club.add("Prince")
science_club.pop()

print(coding_club)
print(science_club)
# Out:
# {'Aman', 'Priya', 'Rahul', 'Ankit', 'Simran', 'Riya', 'Rohit'}
# {'Riya', 'Ankit', 'Rahul'}
# {'Aman', 'Priya'}
# {'Rohit', 'Simran'}
# {'Riya', 'Ankit', 'Rahul'}
# {'Rahul', 'Prince', 'Riya', 'Ankit', 'Rohit', 'Simran'}
# {'Priya', 'Rahul', 'Riya', 'Ankit'}
